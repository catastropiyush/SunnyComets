# %% [markdown]
# # Sungrazer Comets

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Upload images here and find the pixel coordinates
#
# https://pixspy.com/

# %% [markdown]
# New User registration \
# https://sungrazer.nrl.navy.mil/contributors/request_form

# %% [markdown]
# **Guide:** \
#
# https://sungrazer.nrl.navy.mil/index.php/soho_guide
#
# ---

# %% [markdown]
# **Comet Measuring Tools:** \
# https://sungrazer.nrl.navy.mil/tutorial

# %% [markdown]
# **SOHO Data**\
# JPEG:\
# https://soho.nascom.nasa.gov/data/REPROCESSING/Completed/2021/c3/20210421/
#
#
# FITS\
# https://umbra.nascom.nasa.gov/pub/lasco_level05/210421/
#
#
# check this one for latest images
#
# https://umbra.nascom.nasa.gov/pub/lasco/lastimage/level_05/

# %% [markdown]
# C2 images:\
# https://soho.nascom.nasa.gov/data/LATEST/latest-lascoC2.html
#
#
# C3 images:\
# https://soho.nascom.nasa.gov/data/LATEST/latest-lascoC3.html

# %% [markdown]
# Comet Tracks:\
# https://sungrazer.nrl.navy.mil/C2_C3_Comet_Tracks

# %% [markdown]
# Other Links:(you can add relevant material here) \
# https://royalsocietypublishing.org/doi/10.1098/rsta.2016.0257

# %% [markdown]
# Read this blog
#
# https://skyhuntblog.wordpress.com/sungrazing-comets/my-soho-and-stereo-comets/

# %% [markdown]
# **COMET 96 P**
#
# https://sungrazer.nrl.navy.mil/report/reportwb20230128235459
#
# https://sungrazer.nrl.navy.mil/report/reportwb20230128071106

# %% [markdown]
# **Google sheets for data**
#
# https://docs.google.com/spreadsheets/d/1cXM5OZCoIKzjOpkBPyJqxjqNmw8H-KaWF7D1m4JN5mk/edit?usp=sharing

# %%
#18th Feb 2023       Jatin

#Connecting spreadsheet
from google.colab import auth
import gspread
from google.auth import default
#autenticating to google
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# %%
#18th, Feb 2023       Jatin
import pandas as pd
#defining my worksheet
worksheet = gc.open('Data Entry job').sheet1
#get_all_values gives a list of rows
#get(':') gives a list of specific rows 
rows = worksheet.get('D:F')

#Convert to a DataFrame 
df = pd.DataFrame(rows)

#creating columns name
df.columns = df.iloc[0]
df = df.iloc[1:]
df
# Out:
# 0  20230130 69/P C3  NaN  NaN
# 1                54  142  683
# 2               154  148  673
# 3               254  152  663
# 4               354  156  654
# 5               454  159  642
# 6               554  164  634
# 7               654  169  625
# 8               754  174  615
# 9               854  179  605
# 10              954  184  594
# 11             1054  189  585
# 12             1154  194  574
# 13             1254  199  564
# 14             1354  205  554
# 15             1454  211  544
# 16             1554  215  534
# 17             1654  221  525
# 18             1754  227  514
# 19             1854  231  504
# 20             1954  237  494
# 21             2054  246  482
# 22             2154  250  473
# 23             2254  257  462
# 24             2354  264  452

# %%
1024x1024 images
(0,0) upper left
Date: 2023-01-29

08:54 85,829
09:54 88,820
10:54 91,811

# %% [markdown]
# ![20230131_1154_c3_1024.jpg](data:image/jpeg;base64,...)

# %%
Cheers all, I stumbled upon three comets in C2 images of 20120524.

Sungrazer is down, so I have this as my only option to report them all. There is one comet listed in the BAA Comet Section list for 2012, found on May 25 in what I guess was a delayed data cache by Sergei Schmalz. I have a feeling that this is the known comet:
0036 610/1019
0048 613/1012
0125 622/990
0136 625/983
(More positions obviously)

A second comet enters!!      good comet
0224 699/1015
0236 702/1006
0248 705/998
0312 710/980
0324 713/972
0336 716/963
(13 total positions are available)

And then, comet #3 decides to arrive..  bad one
0400 611 1012
0412 616 1005
0424 619 998
0436 623 992
0448 626 985
0500 629 978
0512 632 971
0524 635 964
0536 638 956

# %%
good comet
Images: C2; 1024x1024 images.
(0,0) Upper Left.
2021-10-11
1424 908 1020
1448 888 1002
1512 869 984
1524 857 976
1536 847 966
1548 837 957
_._,_._,_

C3
1024 x 1024 C3 images
(0,0) Upper left
Date: 2021-10-11
....
09:54 638,681
10:06 636,679
10:18 634,678
10:42 630,674
11:06 623,669
11:54 617,663
12:18 613,660

Peter Berrett p.berrett@optusnet.com.au via groups.io 
	
Oct 31, 2021, 1:40 PM
	
to SOHO

Hi again

I have 5 clear positions with this report (the 5th is in the middle of a
streak). I wonder if this will be enough to get confirmed. Seems very
consistent.

Images: C2; 1024x1024 images (non-group)
(0,0) Upper Left
20161127

1712   761  315
1724   769  327
1736   778  340
1748   787  353
1800   797  366

Distance per hour = 76.73909622147559 pixels

# %%
#Jatin and Piyush 3 Feb 2023
a=1230
b=1330
h1 = a//100
m1 = a%100
h2 = b//100
m2 = b%100
if((m2)<(m1)):
  m2=m2+60
  h2=h2-1  
print(h2-h1)
print(m2-m1)
#if((h2-h1)<10):
  z = int(str(h2-h1) + str(m2-m1))
print(z)
# Out:
# 1
# 0
# 10

# %%
20230129 69/P C3
354  	72	874
454	  75	865
554	  78	856
654  	80	849
754	  83	840
854	  86	831
954	  89	822
1054	92	815
1154	95	805
1254	99	795
1354	102	786
1454	105	777
1554	108	769
1654	112	759
1754	116	749
1854	120	740
1954	124	731
2054	127	722
2154	130	713
2254	134	703
2354	139	690

# %%
20230130 69/P C3 
	x	y
54	142	683
154	148	673
254	152	663
354	156	654
454	159	642
554	164	634
654	169	625
754	174	615
854	179	605
954	184	594
1054	189	585
1154	194	574
1254	199	564
1354	205	554
1454	211	544
1554	215	534
1654	221	525
1754	227	514
1854	231	504
1954	237	494
2054	246	482
2154	250	473
2254	257	462
2354	264	452

# %%
20230131 69/P C3

54	270	441
154	276	431
254	281	421
354	287	412
454	295	402
554	302	397
654	308	382
754	314	371
854	321	362
954	328	351
1054	334	342
1154	343	332
1254	350	322
1354 360 315
1454 368 304
1554 375 296
1654 382 287
1754 390 277
1954 404 260
2054 413 251
2154 420 241
2254 429 232
2354 436 223

# %%
20230201 69/P C3		
54	  446	214
154	  452	206
254	  459	195
354	  465	186
454	  472	177
554	  480	171
654	  489	160
754	  497	154
854	  506	147
954	  510	139
1054	521	128
1154	530	124
1254	536	117
1354	543	102
1454	554	100
1554	560  98	
1654	568  92	
1754	576  85	
1854	584  77	
1954	591  71	
2054	599  64	
2154	606  57	
2254	614  51	
2354	622  41

# %%
#added 2400 to the next day time
354  	72	874
454	  75	865
554	  78	856
654  	80	849
754	  83	840
854	  86	831
954	  89	822
1054	92	815
1154	95	805
1254	99	795
1354	102	786
1454	105	777
1554	108	769
1654	112	759
1754	116	749
1854	120	740
1954	124	731
2054	127	722
2154	130	713
2254	134	703
2354	139	690
2454	142	683
2554	148	673
2654	152	663
2754	156	654
2854	159	642
2954	164	634
3054	169	625
3154	174	615
3254	179	605
3354	184	594
3454	189	585
3554	194	574
3654	199	564
3754	205	554
3854	211	544
3954	215	534
4054	221	525
4154	227	514
4254	231	504
4354	237	494
4454	246	482
4554	250	473
4654	257	462
4754	264	452
4854	270	441
4954	276	431
5054	281	421
5154	287	412
5254	295	402
5354	302	397
5454	308	382
5554	314	371
5654	321	362
5754	328	351
5854	334	342
5954	343	332
6054	350	322
6154	360	315
6254	368	304
6354	375	296
6454	382	287
6554	390	277
6754	404	260
6854	413	251
6954	420	241
7054	429	232
7154	436	223
7254	  446	214
7354	  452	206
7454	  459	195
7554	  465	186
7654	  472	177
7754	  480	171
7854	  489	160
7954	  497	154
8054	  506	147
8154	  510	139
8254	521	128
8354	530	124
8454	536	117
8554	543	102
8654	554	100
8754	560  98	
8854	568  92	
8954	576  85	
9054	584  77	
9254	591  71	
9354	599  64	
9454	606  57	
9554	614  51	
9654	622  41

# %%
#Piyush and Jatin 3 Feb 2023
#Comet pixel Speed calculator
import numpy as np
import matplotlib.pyplot as plt
t,x,y = np.loadtxt('data.txt',unpack=True)
N=len(t)
delt=np.zeros(N);velx=np.zeros(N);vely=np.zeros(N)
for i in range(0,len(t)-1):
  h1 = t[i]//100
  m1 = t[i]%100
  h2 = t[i+1]//100
  m2 = t[i+1]%100
  if((m2)<(m1)):
    m2=m2+60
    h2=h2-1  
  #print(h2-h1)
  #print(m2-m1)
  delt[i]=(h2-h1)+(m2-m1)/60
#print(delt)

for j in range(0,len(x)-1):
  velx[j]=(x[j+1]-x[j])/delt[j]
  vely[j]=(y[j+1]-y[j])/delt[j]
#print(velx)
#print(vely)
plt.figure(figsize=(8,6))
plt.ylabel(r'$\frac{pixel}{hr}$',fontsize='20')
plt.xlabel(r'$hrs$',fontsize='15')
plt.plot(t[:-1],velx[:-1],linewidth=2.0,color='#DA3287',label=r'$V_{x}$')
plt.plot(t[:-1],vely[:-1],linewidth=2.0,color='#0A7E8C',label=r'$V_{y}$')
plt.fill_between(t, -10, 0, color='deeppink', alpha=.2,label=r'$C3\sim10\frac{px}{h}$')
plt.fill_between(t, 10, 0, color='deeppink', alpha=.2)
plt.legend()
#print(velx[:-1])
plt.title('202301(29 jan-01 feb) C3 96/P')

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img = mpimg.imread('20230131_0554_c3_1024.jpg') 
plt.figure(figsize=(12,12))
plt.scatter(x,y,marker='+',s=3.5,color='red')
plt.imshow(img)
plt.xlim([0,1024])
plt.ylim([1024,0])
# Out:
# (1024.0, 0.0)

# %%
x-505
# Out:
# array([-433., -430., -427., -425., -422., -419., -416., -413., -410.,
#        -406., -403., -400., -397., -393., -389., -385., -381., -378.,
#        -375., -371., -366., -363., -357., -353., -349., -346., -341.,
#        -336., -331., -326., -321., -316., -311., -306., -300., -294.,
#        -290., -284., -278., -274., -268., -259., -255., -248., -241.,
#        -235., -229., -224., -218., -210., -203., -197., -191., -184.,
#        -177., -171., -162., -155., -145., -137., -130., -123., -115.,
#        -101.,  -92.,  -85.,  -76.,  -69.,  -59.,  -53.,  -46.,  -40.,
#         -33.,  -25.,  -16.,   -8.,    1.,    5.,   16.,   25.,   31.,
#          38.,   49.,   55.,   63.,   71.,   79.,   86.,   94.,  101.,
#         109.,  117.])

# %%
y-531
# Out:
# array([ 343.,  334.,  325.,  318.,  309.,  300.,  291.,  284.,  274.,
#         264.,  255.,  246.,  238.,  228.,  218.,  209.,  200.,  191.,
#         182.,  172.,  159.,  152.,  142.,  132.,  123.,  111.,  103.,
#          94.,   84.,   74.,   63.,   54.,   43.,   33.,   23.,   13.,
#           3.,   -6.,  -17.,  -27.,  -37.,  -49.,  -58.,  -69.,  -79.,
#         -90., -100., -110., -119., -129., -134., -149., -160., -169.,
#        -180., -189., -199., -209., -216., -227., -235., -244., -254.,
#        -271., -280., -290., -299., -308., -317., -325., -336., -345.,
#        -354., -360., -371., -377., -384., -392., -403., -407., -414.,
#        -429., -431., -433., -439., -446., -454., -460., -467., -474.,
#        -480., -490.])

# %%
import numpy as np
import matplotlib.pyplot as plt


def fit_ellipse(x, y):
    """

    Fit the coefficients a,b,c,d,e,f, representing an ellipse described by
    the formula F(x,y) = ax^2 + bxy + cy^2 + dx + ey + f = 0 to the provided
    arrays of data points x=[x1, x2, ..., xn] and y=[y1, y2, ..., yn].

    Based on the algorithm of Halir and Flusser, "Numerically stable direct
    least squares fitting of ellipses'.


    """

    D1 = np.vstack([x**2, x*y, y**2]).T
    D2 = np.vstack([x, y, np.ones(len(x))]).T
    S1 = D1.T @ D1
    S2 = D1.T @ D2
    S3 = D2.T @ D2
    T = -np.linalg.inv(S3) @ S2.T
    M = S1 + S2 @ T
    C = np.array(((0, 0, 2), (0, -1, 0), (2, 0, 0)), dtype=float)
    M = np.linalg.inv(C) @ M
    eigval, eigvec = np.linalg.eig(M)
    con = 4 * eigvec[0]* eigvec[2] - eigvec[1]**2
    ak = eigvec[:, np.nonzero(con > 0)[0]]
    return np.concatenate((ak, T @ ak)).ravel()


def cart_to_pol(coeffs):
    """

    Convert the cartesian conic coefficients, (a, b, c, d, e, f), to the
    ellipse parameters, where F(x, y) = ax^2 + bxy + cy^2 + dx + ey + f = 0.
    The returned parameters are x0, y0, ap, bp, e, phi, where (x0, y0) is the
    ellipse centre; (ap, bp) are the semi-major and semi-minor axes,
    respectively; e is the eccentricity; and phi is the rotation of the semi-
    major axis from the x-axis.

    """

    # We use the formulas from https://mathworld.wolfram.com/Ellipse.html
    # which assumes a cartesian form ax^2 + 2bxy + cy^2 + 2dx + 2fy + g = 0.
    # Therefore, rename and scale b, d and f appropriately.
    a = coeffs[0]
    b = coeffs[1] / 2
    c = coeffs[2]
    d = coeffs[3] / 2
    f = coeffs[4] / 2
    g = coeffs[5]

    den = b**2 - a*c
    if den > 0:
        raise ValueError('coeffs do not represent an ellipse: b^2 - 4ac must'
                         ' be negative!')

    # The location of the ellipse centre.
    x0, y0 = (c*d - b*f) / den, (a*f - b*d) / den

    num = 2 * (a*f**2 + c*d**2 + g*b**2 - 2*b*d*f - a*c*g)
    fac = np.sqrt((a - c)**2 + 4*b**2)
    # The semi-major and semi-minor axis lengths (these are not sorted).
    ap = np.sqrt(num / den / (fac - a - c))
    bp = np.sqrt(num / den / (-fac - a - c))

    # Sort the semi-major and semi-minor axis lengths but keep track of
    # the original relative magnitudes of width and height.
    width_gt_height = True
    if ap < bp:
        width_gt_height = False
        ap, bp = bp, ap

    # The eccentricity.
    r = (bp/ap)**2
    if r > 1:
        r = 1/r
    e = np.sqrt(1 - r)

    # The angle of anticlockwise rotation of the major-axis from x-axis.
    if b == 0:
        phi = 0 if a < c else np.pi/2
    else:
        phi = np.arctan((2.*b) / (a - c)) / 2
        if a > c:
            phi += np.pi/2
    if not width_gt_height:
        # Ensure that phi is the angle to rotate to the semi-major axis.
        phi += np.pi/2
    phi = phi % np.pi

    return x0, y0, ap, bp, e, phi


def get_ellipse_pts(params, npts=100, tmin=0, tmax=2*np.pi):
    """
    Return npts points on the ellipse described by the params = x0, y0, ap,
    bp, e, phi for values of the parametric variable t between tmin and tmax.

    """

    #x0, y0, ap, bp, e, phi = params
    # A grid of the parametric variable, t.
    #t = np.linspace(tmin, tmax, npts)
    #x = x0 + ap * np.cos(t) * np.cos(phi) - bp * np.sin(t) * np.sin(phi)
    #y = y0 + ap * np.cos(t) * np.sin(phi) + bp * np.sin(t) * np.cos(phi)
    #return x, y


if __name__ == '__main__':
    # Test the algorithm with an example elliptical arc.
    npts = 250
    tmin, tmax = np.pi/6, 4 * np.pi/3
    x0, y0 = 4, -3.5
    ap, bp = 7, 3
    phi = np.pi / 4
    # Get some points on the ellipse (no need to specify the eccentricity).
    #x, y = get_ellipse_pts((x0, y0, ap, bp, None, phi), npts, tmin, tmax)
    noise = 0.1
    #x += noise * np.random.normal(size=npts) 
    #y += noise * np.random.normal(size=npts)

    coeffs = fit_ellipse(x, y)
    print('Exact parameters:')
    print('x0, y0, ap, bp, phi =', x0, y0, ap, bp, phi)
    print('Fitted parameters:')
    print('a, b, c, d, e, f =', coeffs)
    x0, y0, ap, bp, e, phi = cart_to_pol(coeffs)
    print('x0, y0, ap, bp, e, phi = ', x0, y0, ap, bp, e, phi)

    plt.plot(x, y, 'x')     # given points
    x, y = get_ellipse_pts((x0, y0, ap, bp, e, phi))
    plt.plot(x, y)
    plt.show()
# Out:
# Exact parameters:
# x0, y0, ap, bp, phi = 4 -3.5 7 3 0.7853981633974483
# Fitted parameters:
# a, b, c, d, e, f = [ -0.50620766   0.69821746  -0.50620766   6.49342235  -6.33632342
#  -16.37756323]
# x0, y0, ap, bp, e, phi =  3.999999999999658 -3.5000000000001243 6.999999999999708 2.9999999999998876 0.9035079029052504 0.785398163397474
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-78e2e240bfce> in <module>
#     132
#     133     plt.plot(x, y, 'x')     # given points
# --> 134     x, y = get_ellipse_pts((x0, y0, ap, bp, e, phi))
#     135     plt.plot(x, y)
#     136     plt.show()
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
x1=np.linspace(-5,5,100)
y1=np.linspace(-5,5,100)
plt.figure(figsize=(8,6))
plt.plot(x1,(25-x1**2)**(0.5))
plt.plot(x1,-(25-x1**2)**(0.5))

# %%
x1=np.linspace(-5,5,100)
y1=np.linspace(-5,5,100)
plt.figure(figsize=(8,6))
e=0.5
plt.plot(x1,((25-x1**2)*(1-e**2))**(0.5),color='black')
plt.plot(x1,((25-x1**2)*(1-0.95**2))**(0.5),color='Red')
plt.plot(x1,-((25-x1**2)*(1-0.95**2))**(0.5),color='Red')
plt.plot(x1,-((25-x1**2)*(1-e**2))**(0.5),color='black')

# %%
t,x,y = np.loadtxt('data.txt',unpack=True)
N=len(t)
dis=np.zeros(N)
for i in range(0,len(x)):
  dis[i]=((x[i]-505)**2+(y[i]-531)**2)**(0.5)
plt.plot(x,dis)
plt.plot(y,dis)

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img = mpimg.imread('20230131_0054_c3_1024.jpg') 
plt.figure(figsize=(12,12))
plt.scatter(x,y,marker='+',s=21.5,color='magenta')
plt.imshow(img)
plt.xlim([0,1024])
plt.ylim([1024,0])
# Out:
# (1024.0, 0.0)

# %%
#Piyush and Jatin 3 Feb 2023
#Comet pixel Speed calculator
t,x,y = np.loadtxt('datu.txt',unpack=True)
N=len(t)
delt=np.zeros(N);velx=np.zeros(N);vely=np.zeros(N)
for i in range(0,len(t)-1):
  h1 = t[i]//100
  m1 = t[i]%100
  h2 = t[i+1]//100
  m2 = t[i+1]%100
  if((m2)<(m1)):
    m2=m2+60
    h2=h2-1  
  #print(h2-h1)
  #print(m2-m1)
  delt[i]=(h2-h1)+(m2-m1)/60
#print(delt)

for j in range(0,len(x)-1):
  velx[j]=(x[j+1]-x[j])/delt[j]
  vely[j]=(y[j+1]-y[j])/delt[j]
#print(velx)
#print(vely)
plt.figure(figsize=(8,6))
plt.ylabel(r'$\frac{pixel}{hr}$',fontsize='20')
plt.xlabel(r'$Hours$',fontsize='15')
plt.plot(t[:-1],velx[:-1],linewidth=2.0,color='#DA3287',label=r'$V_{x}$')
plt.plot(t[:-1],vely[:-1],linewidth=2.0,color='#0A7E8C',label=r'$V_{y}$')
plt.fill_between(t, -10, 0, color='deeppink', alpha=.2,label=r'$C3\sim10\frac{px}{h}$')
plt.fill_between(t, 10, 0, color='deeppink', alpha=.2)
plt.legend()
plt.title('20230130 C3 96/P')
# Out:
# Text(0.5, 1.0, '20230130 C3 96/P')

# %%
#Piyush and Jatin 3 Feb 2023
#Comet pixel Speed calculator
t,x,y = np.loadtxt('datu.txt',unpack=True)
N=len(t)
delt=np.zeros(N);velx=np.zeros(N);vely=np.zeros(N)
for i in range(0,len(t)-1):
  h1 = t[i]//100
  m1 = t[i]%100
  h2 = t[i+1]//100
  m2 = t[i+1]%100
  if((m2)<(m1)):
    m2=m2+60
    h2=h2-1  
  #print(h2-h1)
  #print(m2-m1)
  delt[i]=(h2-h1)+(m2-m1)/60
#print(delt)

for j in range(0,len(x)-1):
  velx[j]=(x[j+1]-x[j])/delt[j]
  vely[j]=(y[j+1]-y[j])/delt[j]
#print(velx)
#print(vely)
plt.figure(figsize=(8,6))
plt.ylabel(r'$\frac{pixel}{hr}$',fontsize='20')
plt.xlabel(r'$Hours$',fontsize='15')
plt.plot(t[:-1],velx[:-1],linewidth=2.0,color='#DA3287',label=r'$V_{x}$')
plt.plot(t[:-1],vely[:-1],linewidth=2.0,color='#0A7E8C',label=r'$V_{y}$')
plt.fill_between(t, -10, 0, color='deeppink', alpha=.2,label=r'$C3\sim10\frac{px}{h}$')
plt.fill_between(t, 10, 0, color='deeppink', alpha=.2)
plt.legend()
plt.title('20230130 C3 96/P')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-416be53a51cb> in <module>
#       1 #Piyush and Jatin 3 Feb 2023
#       2 #Comet pixel Speed calculator
# ----> 3 t,x,y = np.loadtxt('datu.txt',unpack=True)
#       4 N=len(t)
#       5 delt=np.zeros(N);velx=np.zeros(N);vely=np.zeros(N)
#
# NameError: name 'np' is not defined

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
image_file  = fits.open('https://soho.nascom.nasa.gov/data/REPROCESSING/Completed/2023/c3/20230128/20230128_0006_c3_1024.jpg')
image_file1 = fits.open('https://umbra.nascom.nasa.gov/pub/lasco/lastimage/level_05/221228/c3/33737099.fts')

# %%
image_data = image_file[0].data
image_data1 = image_file[0].data
plt.figure(figsize=(10,10))
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(image_data, cmap='plasma')
ax2.imshow(image_data1, cmap='plasma')
#plt.imshow(image_data, cmap='plasma')
#plt.imshow(image_data1, cmap='plasma')
#plt.clim(-1000,5000)

# %%
plt.figure(figsize=(6,6))
plt.plot(x,y)
plt.xlim([0,1024])
plt.ylim([1024,0])

# %% [markdown]
# # Programming

# %%
#Last update Khushi :)
program projectile
implicit none
integer :: theta
real :: angle, R
real, parameter :: pi = 4.0*atan(1.0), u =30.0, g=9.8
open(1, file = 'projectile.dat', action = 'write')
do theta = 0, 90
angle = (theta*pi)/180.0
R = (u**2*sin(2*angle))/g
print*, theta, R
write (1,*) theta, R
end do
close(1)
end program projectile

# %% [markdown]
# **Qudratic Equation Solver**

# %%
#Last update Rahul
#Quadratic equation solver
program root_quadratic
! Design and write a program to solve for the roots of a quadratic equation, regardless of type
    implicit none
    real::a,b,c,x1,x2,x3,x4
    print*,"The quadratic equation is in the form  (ax^2 + bx + c) = 0"
    print*,"Enter the coeffiencts a, b, c respectively"
    read(*,*)a,b,c
    x1=(-b)/2*a
    x2=b**2-(4*a*c)
    x3=sqrt(x2)/(2*a)
    x4=sqrt(-x2)/(2*a)
     re_al: if (x2>=0) then
        print*,"The  roots of the quadratic equation  are real and roots are"
        print*,x1 + x3
        print*,x1 - x3
    else
        print*,"The  roots are complex  and are given by"
        print*,x1,"+   i",x4
        print*,x1,"-   i",x4
    end if re_al
end  program root_quadratic

# %% [markdown]
# **Days in week**

# %%
  #Last update Rahul
  #Days in a week
  program ca_ase
  ! Write a program that reads an integer from the keyboard, and displays the day of the week corresponding to that integer.
  ! Be sure to handle the case of an illegal input value
      integer:: day
      print*,"Enter any number from (1 - 7)"
      read(*,*)day
      print*,"The day number",day,"of the week is"
      week: select case (day)
  case (1)
      print*,"Sunday"
  case(2)
      print*,"Monday"
  case(3)
      print*,"Tuesday"
  case(4)
      print*,"Wednesday"
  case(5)
      print*,"Thursday"
  case(6)
      print*,"Friday"
  case(7)
      print*,"Saturday"
  case default
      print*,"Entered  value is out of range"
  end select week
  end program ca_ase

# %% [markdown]
# *Differential Equations*

# %% [markdown]
# $$y(x+h)=y(x)+hy'(x)$$ \
# **Explicit Euler**\
# $$y_{n+1}=y_{n}+hf'(x_n,y_n)$$ \
# **Implicit Euler**
# $$y_{n+1}=y_{n}+hf'(x_{n+1},y_{n+1})$$

# %%
#Last update Piyush
#Adam Bashforth PC
program Predictor
IMPLICIT NONE

REAL::a,b,h,y_0,f_prime
INTEGER::N,i
real, allocatable :: x(:), y(:)

a=0
b=4
h=0.1
y_0=0

N=INT((b-a)/h) !Number of steps
allocate(x(N),y(N))

x(1) = a 
y(1) = y_0
x(2) = a+h       !Adam Bashforth 2 Step Method
y(2) = y_0+h*f_prime(x(1),y(1))

do i=2,N
    y(i+1) = y(i) + (h/2)*(3*f_prime(x(i),y(i))-f_prime(x(i-1),y(i-1)))
    x(i+1) = x(i) + h
    y(i+1) = y(i) + (h/2)*(f_prime(x(i+1),y(i+1))+f_prime(x(i),y(i)))

end do

do i = 1,N
    write(*,*) x(i),y(i)
    x(i)=x(i)+h
  end do

end program Predictor

REAL function f_prime(x1,y1)
REAL::x1,y1
  f_prime=-0.5*EXP(x1/2)*SIN(5*x1)+5*EXP(x1/2)*COS(5*x1)+y1
return
end function
# Out:
#   File "<tokenize>", line 33
#     end do
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# **Income tax calculator**
#
# Chapman problem :3-10
#
# **using select case**

# %%
# Last Upadated by Rahul 
# Income tax calculator
program income_tax
    implicit none

    integer::x
    real::t,t1

    print*,"Enter your income in $"
    read(*,*)x

select case (x)
    ! (for income 0 - 6000 there is no tax)
    ! (for income 6001 - 34000, 15¢ tax for each $1 over $6000 )
    ! (for income 34000 - 80000, the tax is $4200 plus 30¢ for each $1 over $34,000  )
    ! (for income 80000 - 180000, the tax is $18,000 plus 40¢ for each $1 over $80,000  )
    ! (for income greater than 180000 , the tax is $58,000 plus 45¢ for each $1 over $180,000)
    case(:6000) 
        t=0.
    case(6001:34000)
        t=(real(x)-6000.)*(15.0/100.)
    case(34001:80000)
        t=(4200.)+(real(x)-34000.)*(30./100.)
    case(80001:180000)
        t=(180000.)+(real(x)-80000.)*(40./100.)
    case(180001:)
        t=(58000.)+(real(x)-180000.)*(45./100.)
    end select

    t1=t+(x*(1.5/100.0))
    ! A flat 1.5 percent Medicare levy is charged on all income

    write(*,*)"The tax amount payable is =",t1,"$"
end program income_tax
# Out:
#   File "<ipython-input-1-39beccba754f>", line 3
#     program income_tax
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Simple multiplicator**
#
# (using while loop)

# %%
#last updated by Rahul
#simple multiplicator 
program multi
    implicit none
    integer::a,b,n
    do
    print*,"enter the numbers"
    read(*,*)a,b
    print*,"product =",a,"x",b,"=",a*b
    print*,"to  stop  press 0 & to continue press any number"
    read*,n
    if(n==0)exit
    end do
end program multi

# %% [markdown]
# 2.26 Aircraft Turning radius problem

# %%
#last edited by A Rahman
program aircract_turning_radius
    implicit none
    real, parameter::mach=340 !m/s
    real,parameter::g=9.81 !m/s2
    real::a,ag,v,vm,r
    print*,"Enter the velocity of the aircraft(In Mach): "
    read(*,*)vm
    v=vm*340
    print*,"Enter the acceleration of the aircraft(in g): "
    read(*,*)ag
    a=ag*9.8
    r=(v**2)/a
    print*,"the turning radius of the aircraft for acceleration:",ag,"g(m/sec2) and velocity:",vm," Mach is ",r," meter"

end program

# %% [markdown]
# Example 2.4 Calculate the real power, reactive power and apparent power

# %%
#last update A Rahman
program power
implicit none
real, parameter::deg2rad=0.01745329
real:: amps 	! current(A)
real::p 	! real power(W)
real::pf	! power factor(No unit)
real::q		! reactive power(VAR)
real::s 	! apparent power(VA)
real::theta	! impedance angle(degrees)
real::volts	! rms voltage(volts)
real::z		! impedance(ohms)


write(*,*)"Enter the value of rms voltage of the source:"
read(*,*)volts
write(*,*)"Enter the values of the magnitude of the impedance(ohms) and angles(degree)"
read(*,*)z,theta
amps=volts/z
p=volts*amps*cos(theta*deg2rad)
q=volts*amps*sin(theta*deg2rad)
s=volts*amps
pf=cos(theta*deg2rad)
print *,'voltage=',volts,'volts'
print *, 'impedance',z,'ohms at theta',theta,'degrees'
print *,'current',amps,'amps'
print *,'real power',p, 'watts'
print *,'reactive power',q,'VAR'
print *,'apparent power',s, 'VA'
print *,'power factor',pf

end program power

# %% [markdown]
# 2.18 write a program to calculate the hypotenuse of a right triangle , given the lentghs of its two sides.

# %%
#last update A Rahman
!2.18
program hypotenuse_len
implicit none
real::hy,ba,he
write(*,*),"Enter the lengths of the base and the height of thé right angled triangle: "
read(*,*)ba,he 
hy=sqrt(ba**2+he**2)
print*,"The length of the hypotenuse is ",hy,"."
end program hypotenuse_len

# %% [markdown]
# Example 2.5 Carbon Dating From Chapmen Book

# %%
#last update A Rahman
program carbondating
implicit none
real, parameter::lambda=0.00012097
real::time,percent,fraction
write(*,*)"Enter the % of C-14 sample: "
read(*,*)percent


print*,"The ramaining C-14 is",percent,"%"

fraction=percent/100
time=(-1/lambda)*log(fraction)


print*,"The age of the sample is",time,"years."
end program carbondating

# %% [markdown]
# Caclulate the value of pi

# %%
#last update A Rahman
Program pi
implicit none 
real(kind=16)::a,c
read(*,*)c
a=2*asin(c)
Print *,a
End Program pi

# %% [markdown]
# **TABLE CALCULATER**

# %%
# last updated by MD AMAN
# table calculater
program table calculater
        implicit none

        integer ::x,y,i
        print*, 'enter the number of which table you want'
        read(*,*)x

        do i = 1,100
        y = x*i
        write(*,*) x,"x",i,"=",y
        end do

end program table calculater

# %% [markdown]
# **Calculator**

# %%
#last updated by Khushi
# calculator
program calculator
      implicit none
      real::a,b
      integer::i,n,k,l,n_fact
      # !n_fact=1

      do
      n_fact=1
      print*,"select the operation you want to perform"
      print*,"================================"
      print*,"for addition press         : 1"
      print*,"for substraction press     : 2"
      print*,"for multiplication press   : 3"
      print*,"for division press         : 4"
      print*,"for factorial press        : 5"
      print*,"================================"
      read(*,*)i

      k_c_1:if(i>=1.and.i<=4)then
              print*,"enter the two numbers"
              read(*,*)a,b
      else if(i==5)then
              print*,"enter the number"
              read(*,*)n
      else
              print*,"ERROR"
      end if k_c_1

      select case(i)
      case(1)
              print*,"operation :",a,"+",b,"=",a+b
      case(2)
              print*,"operation :",a,"-",b,"=",a-b
      case(3)
              print*,"operation :",a,"x",b,"=",a*b
      case(4)
              print*,"operation :",a,"/",b,"=",a/b
      case(5)

              k_c: do k=1,n

              n_fact=n_fact*k
              end do k_c
              print*,"operation :",n,"!","=",n_fact
      case default
              print*,"ERROR"
              end select

      print*,"to stop press 0 to continue press any number"
      read(*,*)l

      if(l==0)exit
      end do
      end program calculator

# %% [markdown]
# **Range,time of flight, max height**
#
# data for gnu plot

# %%
#last updated by Rahul
#data for gnu plot(range, max height,time of flight)
program projectile
    implicit none

    integer::u,x
    real::t,r,h,s,s2

    ! u : initial velocity
    ! x : angle
    ! t : time  of  flight
    ! r : range of the projectile
    ! h : max height of the projectile 
    ! s : sine value
    ! s2: Sin^2 vlaue

    print*,"Give the initial velocity (integer value only)"
    read(*,*)u

    do x=0,90
        s=sind(real(x))
        s2=sind(real(x))**2
        t=((2.0)*u*sind(real(x)))/9.8     
        r=((u**2)*sind((2.0)*real(x)))/9.8
        h=((u**2)*(sind(real(x))**2))/((2.0)*9.8)
        print*,x,s,s2,t,r,h
    end do

end program projectile

# %% [markdown]
# **Factorial**

# %%
program factorial
      implicit none
      integer::i,x,k
      real(kind=32)::n
      first: do

      print*,"Enter the number"
      read(*,*)x
      n=1
      do i=1,x
      n=n*i
      end do
      print*,n

      print*,"to stop press 0 to continue press any other number"
      read(*,*)k
      if(k==0)exit
      end do first

      end program factorial
